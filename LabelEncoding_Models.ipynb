# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
cancer_data = pd.read_csv("/content/breast-cancer.csv")

# %%
cancer_data.head()
# Out:
#          id diagnosis  radius_mean  ...  concave points_worst  symmetry_worst  fractal_dimension_worst
# 0    842302         M        17.99  ...                0.2654          0.4601                  0.11890
# 1    842517         M        20.57  ...                0.1860          0.2750                  0.08902
# 2  84300903         M        19.69  ...                0.2430          0.3613                  0.08758
# 3  84348301         M        11.42  ...                0.2575          0.6638                  0.17300
# 4  84358402         M        20.29  ...                0.1625          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
cancer_data.tail()
# Out:
#          id diagnosis  radius_mean  ...  concave points_worst  symmetry_worst  fractal_dimension_worst
# 564  926424         M        21.56  ...                0.2216          0.2060                  0.07115
# 565  926682         M        20.13  ...                0.1628          0.2572                  0.06637
# 566  926954         M        16.60  ...                0.1418          0.2218                  0.07820
# 567  927241         M        20.60  ...                0.2650          0.4087                  0.12400
# 568   92751         B         7.76  ...                0.0000          0.2871                  0.07039
#
# [5 rows x 32 columns]

# %%
cancer_data["diagnosis"].value_counts() #Baynain and Malginant
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
label_encode = LabelEncoder()
labels = label_encode.fit_transform(cancer_data.diagnosis)
cancer_data["target"] = labels
cancer_data.head()
# Out:
#          id diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst  target
# 0    842302         M        17.99  ...          0.4601                  0.11890       1
# 1    842517         M        20.57  ...          0.2750                  0.08902       1
# 2  84300903         M        19.69  ...          0.3613                  0.08758       1
# 3  84348301         M        11.42  ...          0.6638                  0.17300       1
# 4  84358402         M        20.29  ...          0.2364                  0.07678       1
#
# [5 rows x 33 columns]

# %%
cancer_data["target"].value_counts()
# Out:
# target
# 0    357
# 1    212
# Name: count, dtype: int64

# %%
cc_df = pd.read_csv("/content/credit_data.csv")

# %%
cc_df.head()
# Out:
#    Time        V1        V2        V3        V4  ...       V26       V27       V28  Amount  Class
# 0     0 -1.359807 -0.072781  2.536347  1.378155  ... -0.189115  0.133558 -0.021053  149.62    0.0
# 1     0  1.191857  0.266151  0.166480  0.448154  ...  0.125895 -0.008983  0.014724    2.69    0.0
# 2     1 -1.358354 -1.340163  1.773209  0.379780  ... -0.139097 -0.055353 -0.059752  378.66    0.0
# 3     1 -0.966272 -0.185226  1.792993 -0.863291  ... -0.221929  0.062723  0.061458  123.50    0.0
# 4     2 -1.158233  0.877737  1.548718  0.403034  ...  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
cc_df.tail()
# Out:
#          Time        V1        V2        V3        V4  ...       V26       V27       V28  Amount  Class
# 105062  69348  1.255690 -1.393540  0.692738 -1.289430  ... -0.087901  0.054217  0.043817  116.00    0.0
# 105063  69349 -1.250199  0.123183  1.051709 -0.236427  ... -0.496523 -0.042176  0.161224    3.99    0.0
# 105064  69349 -1.925153 -0.140133  2.456659  0.148112  ...  0.515140  0.207773 -0.090777    4.69    0.0
# 105065  69349  1.277856 -0.027651  0.249167  0.697814  ...  0.489582 -0.017759  0.002991   10.00    0.0
# 105066  69350 -1.176438  0.811442  0.539281 -1.505794  ...       NaN       NaN       NaN     NaN    NaN
#
# [5 rows x 31 columns]

# %%
cc_df["Class"].value_counts()
# Out:
# Class
# 0.0    104834
# 1.0       232
# Name: count, dtype: int64

# %%
legit = cc_df[cc_df.Class == 0]
fraud = cc_df[cc_df.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (104834, 31)
# (232, 31)

# %%
legit_sample = legit.sample(n = 492)

# %%
print(legit_sample)
# Out:
#         Time        V1        V2        V3        V4  ...       V26       V27       V28  Amount  Class
# 96733  65908 -0.349307  1.040311  0.950888 -0.250055  ...  0.106809  0.239719  0.080961    9.83    0.0
# 91431  63469 -2.398697 -1.378352  2.587481  0.144631  ... -0.196913  0.132244  0.059499  199.50    0.0
# 64442  51146 -0.301645  0.828448  1.961765  0.055840  ...  0.185444 -0.122557 -0.162484   11.75    0.0
# 88996  62378 -0.616877 -0.319160  0.008284 -1.316676  ...  1.071429 -0.095515  0.283259  258.00    0.0
# 65183  51464  1.116012 -0.764563  0.816508  0.594795  ... -0.359368  0.075326  0.056307  120.00    0.0
# ...      ...       ...       ...       ...       ...  ...       ...       ...       ...     ...    ...
# 10888  18671 -0.746532  0.554874  2.538925 -1.673693  ... -0.814541  0.081385  0.071236   11.85    0.0
# 22246  32126  1.254005  0.295544  0.289061  0.701773  ...  0.096904 -0.028302  0.029315    2.67    0.0
# ...

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#         Time        V1        V2        V3        V4  ...       V26       V27       V28  Amount  Class
# 96733  65908 -0.349307  1.040311  0.950888 -0.250055  ...  0.106809  0.239719  0.080961    9.83    0.0
# 91431  63469 -2.398697 -1.378352  2.587481  0.144631  ... -0.196913  0.132244  0.059499  199.50    0.0
# 64442  51146 -0.301645  0.828448  1.961765  0.055840  ...  0.185444 -0.122557 -0.162484   11.75    0.0
# 88996  62378 -0.616877 -0.319160  0.008284 -1.316676  ...  1.071429 -0.095515  0.283259  258.00    0.0
# 65183  51464  1.116012 -0.764563  0.816508  0.594795  ... -0.359368  0.075326  0.056307  120.00    0.0
#
# [5 rows x 31 columns]

# %%
new_dataset.tail()
# Out:
#          Time         V1         V2        V3  ...       V27       V28  Amount  Class
# 102443  68207 -13.192671  12.785971 -9.906650  ...  1.269566  0.939407    1.00    1.0
# 102444  68207 -13.192671  12.785971 -9.906650  ...  1.269566  0.939407    1.00    1.0
# 102445  68207 -13.192671  12.785971 -9.906650  ...  1.269566  0.939407    1.00    1.0
# 102446  68207 -13.192671  12.785971 -9.906650  ...  1.269566  0.939407    1.00    1.0
# 102782  68357   1.232604  -0.548931  1.087873  ...  0.080805  0.035427   19.59    1.0
#
# [5 rows x 31 columns]

# %%
new_dataset.shape
# Out:
# (724, 31)

# %%
new_dataset["Class"].value_counts()
# Out:
# Class
# 0.0    492
# 1.0    232
# Name: count, dtype: int64
